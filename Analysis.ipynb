# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# 1) Data Collection

# %%
df=pd.read_csv('stud.csv')

# %%
df
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
# 1) show the shape of the dataset 
df.shape
# Out:
# (1000, 8)

# %%
# 2) show the column names 
df.columns
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
# 3) show the index 
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# 4) show the values 
df.values
# Out:
# array([['female', 'group B', "bachelor's degree", ..., 72, 72, 74],
#        ['female', 'group C', 'some college', ..., 69, 90, 88],
#        ['female', 'group B', "master's degree", ..., 90, 95, 93],
#        ...,
#        ['female', 'group C', 'high school', ..., 59, 71, 65],
#        ['female', 'group D', 'some college', ..., 68, 78, 77],
#        ['female', 'group D', 'some college', ..., 77, 86, 86]],
#       shape=(1000, 8), dtype=object)

# %%
# 5) check for missing values
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
# 6) check for duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 7) check for duplicated columns
df.T
# Out:
#                                            0             1                2    \
# gender                                  female        female           female
# race_ethnicity                         group B       group C          group B
# parental_level_of_education  bachelor's degree  some college  master's degree
# lunch                                 standard      standard         standard
# test_preparation_course                   none     completed             none
# math_score                                  72            69               90
# reading_score                               72            90               95
# writing_score                               74            88               93
#
#                                             3             4    \
# gender                                     male          male
# race_ethnicity                          group A       group C
# parental_level_of_education  associate's degree  some college
# ...

# %%
df.T.duplicated().sum()
# Out:
# np.int64(0)

# %%
# 8) check data types 
df.dtypes
# Out:
# gender                         object
# race_ethnicity                 object
# parental_level_of_education    object
# lunch                          object
# test_preparation_course        object
# math_score                      int64
# reading_score                   int64
# writing_score                   int64
# dtype: object

# %%
# 9) display the first 10 rows of dataset 
df.head(10)
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
# 10) display the last 10 rows of dataset 
df.tail(10)
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 990               completed          86             81             75
# ...

# %%
# 11) Get summary statistics of numerical columns 
df.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
# 12) check correlation 
cm=df.corr(numeric_only=True)
cm
# Out:
#                math_score  reading_score  writing_score
# math_score       1.000000       0.817580       0.802642
# reading_score    0.817580       1.000000       0.954598
# writing_score    0.802642       0.954598       1.000000

# %%
# 13) heatmap 
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
# 14) count unique value in each categorical columns 
col=df.columns 
print(col)
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course', 'math_score', 'reading_score',
#        'writing_score'],
#       dtype='object')

# %%
categorical_columns=col[0:5] 
print(categorical_columns)
# Out:
# Index(['gender', 'race_ethnicity', 'parental_level_of_education', 'lunch',
#        'test_preparation_course'],
#       dtype='object')

# %%
for i in categorical_columns:
    print(i,":",df[i].unique(),"count:",df[i].nunique()) 
    print('\n')
# Out:
# gender : ['female' 'male'] count: 2
#
#
# race_ethnicity : ['group B' 'group C' 'group A' 'group D' 'group E'] count: 5
#
#
# parental_level_of_education : ["bachelor's degree" 'some college' "master's degree" "associate's degree"
#  'high school' 'some high school'] count: 6
#
#
# lunch : ['standard' 'free/reduced'] count: 2
#
#
# test_preparation_course : ['none' 'completed'] count: 2

# %%
# 15) find the average score in each subject grouped by gender 
df.groupby('gender')[['math_score','reading_score','writing_score']].mean()
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
# using pivot table 
pv=pd.pivot_table(data=df,index=['gender'],values=['math_score','reading_score','writing_score'],aggfunc=['mean'])
print(pv)
# Out:
#              mean
#        math_score reading_score writing_score
# gender
# female  63.633205     72.608108     72.467181
# male    68.728216     65.473029     63.311203

# %%
sns.barplot(x='gender',y='math_score',data=df,hue='test_preparation_course')
# Out:
# <Axes: xlabel='gender', ylabel='math_score'>

# %%
# 16) check distribution using histplot 
sns.histplot(df['reading_score'],kde=True)
# Out:
# <Axes: xlabel='reading_score', ylabel='Count'>

# %%
df['writing_score'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
# 17) compare average math score between students who completed the test prepartion course and those who didn't 
df.groupby('test_preparation_course')['math_score'].mean()
# Out:
# test_preparation_course
# completed    69.695531
# none         64.077882
# Name: math_score, dtype: float64

# %%
# 18) which race ethnicity group has the highest average writing score 
df_new=df.groupby('race_ethnicity')['writing_score'].mean()
df_new
# Out:
# race_ethnicity
# group A    62.674157
# group B    65.600000
# group C    67.827586
# group D    70.145038
# group E    71.407143
# Name: writing_score, dtype: float64

# %%
result=df_new.reset_index()

# %%
result
# Out:
#   race_ethnicity  writing_score
# 0        group A      62.674157
# 1        group B      65.600000
# 2        group C      67.827586
# 3        group D      70.145038
# 4        group E      71.407143

# %%
result.sort_values('writing_score',ascending=False)
# Out:
#   race_ethnicity  writing_score
# 4        group E      71.407143
# 3        group D      70.145038
# 2        group C      67.827586
# 1        group B      65.600000
# 0        group A      62.674157

# %%
# group E has the highest average writingscore

# %%
# 19) find the top 5 students based on average of all three subject 
df['average_score']=df[['math_score','reading_score','writing_score']].mean(axis=1)

# %%
top_5 = df.sort_values('average_score',ascending=False).head(5)

# %%
top_5
# Out:
#      gender race_ethnicity parental_level_of_education     lunch  \
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
# 458  female        group E           bachelor's degree  standard
# 114  female        group E           bachelor's degree  standard
# 712  female        group D                some college  standard
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# 916               completed         100            100            100
# 962                    none         100            100            100
# 458                    none         100            100            100
# 114               completed          99            100            100
# 712                    none          98            100             99
#
#      average_score
# 916     100.000000
# 962     100.000000
# 458     100.000000
# 114      99.666667
# 712      99.000000

# %%
# 20) check distribution of math score in data using kde 
df['math_score'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.histplot(df['math_score'],kde=True)
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %%
# 21 using scatterplot show the relation between math_score and writing_score group by gender 
sns.scatterplot(x='math_score',y='writing_score',data=df,hue='gender')
# Out:
# <Axes: xlabel='math_score', ylabel='writing_score'>

# %%
# 22) check and plot genderwise count of student separated by ethinic group 
sns.countplot(x='gender',data=df,hue='race_ethnicity')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
# 23) do students with standard lunch performed better than those with free/reduced lunch? 
df.groupby('lunch')[['math_score','reading_score','writing_score']].mean()
# Out:
#               math_score  reading_score  writing_score
# lunch
# free/reduced   58.921127      64.653521      63.022535
# standard       70.034109      71.654264      70.823256

# %%
# 24) which subject has the average difference between male and female students 
df.groupby('gender')[['math_score','reading_score','writing_score']].mean()
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
# 25) find students who scored above 90 in all three subjects 
df[(df['math_score']>90) & (df['reading_score']>90) & (df['writing_score']>90)]
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 114  female        group E           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 546  female        group A            some high school      standard
# 566  female        group E           bachelor's degree  free/reduced
# 571    male        group A           bachelor's degree      standard
# 594  female        group C           bachelor's degree      standard
# 625    male        group D                some college      standard
# 685  female        group E             master's degree      standard
# 712  female        group D                some college      standard
# ...

# %%
# 26) among diffrent parental education levels which groups childern perform best on average 
df.groupby('parental_level_of_education')[['math_score','reading_score','writing_score']].mean()
# Out:
#                              math_score  reading_score  writing_score
# parental_level_of_education
# associate's degree            67.882883      70.927928      69.896396
# bachelor's degree             69.389831      73.000000      73.381356
# high school                   62.137755      64.704082      62.448980
# master's degree               69.745763      75.372881      75.677966
# some college                  67.128319      69.460177      68.840708
# some high school              63.497207      66.938547      64.888268

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
#  8   average_score                1000 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %%
# using pie plot show gender wise average reading score in percantege
new=pd.pivot_table(data=df,index='gender',values='reading_score',aggfunc='mean')

# %%
new
# Out:
#         reading_score
# gender
# female      72.608108
# male        65.473029

# %%
plt.pie(x=new['reading_score'],labels=new.index,autopct='%1.1f%%') 
plt.show()

# %%
# using pie plot show gender wise average math score in percatege
new=pd.pivot_table(data=df,index='gender',values='math_score',aggfunc='mean')

# %%
new
# Out:
#         math_score
# gender
# female   63.633205
# male     68.728216

# %%
plt.pie(x=new['math_score'],labels=new.index,autopct='%1.1f%%') 
plt.show()

# %%
# using pie plot show gender wise average writing score in percantege 
new=pd.pivot_table(data=df,index='gender',values='writing_score',aggfunc='mean')

# %%
new
# Out:
#         writing_score
# gender
# female      72.467181
# male        63.311203

# %%
plt.pie(x=new['writing_score'],labels=new.index,autopct='%1.1f%%') 
plt.show()

# %%
# gender wise math score and writing score 
sns.scatterplot(data=df,x='math_score',y='writing_score',hue='gender')
# Out:
# <Axes: xlabel='math_score', ylabel='writing_score'>

# %%
# violinplot 
sns.violinplot(x='test_preparation_course',y='average_score',data=df)
# Out:
# <Axes: xlabel='test_preparation_course', ylabel='average_score'>

# %%
# countplot 
sns.countplot(x='lunch',data=df,hue='gender')
# Out:
# <Axes: xlabel='lunch', ylabel='count'>

# %%
a=sns.FacetGrid(col='gender',row='race_ethnicity',data=df) 
a.map(plt.hist,'math_score')

# %%
# Insights 

# 1) Students whose parents have higher education level genrally score better. 

# 2) Parent education shows positive correction. 

# 3) Students with standard lunch tend to perform better than those with free lunch.

# 4) Students who completed test preparation score higher than other student 

# 5) Female students tend to out perform male student score higher in math 

# 6) G
